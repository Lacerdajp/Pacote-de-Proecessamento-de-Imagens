# %%
from image_processing_jpls.processing import combination,transformation
from image_processing_jpls.ultil import io,plot
image1=io.imread(r"C:\Users\joaop\Downloads\Floresta_Verde2.jpg")
image2=io.imread(r"C:\Users\joaop\Downloads\flores florida.jpg")
plot.plot_image(image1)
plot.plot_image(image2)

# %%
result=combination.transfer_histogram(image1,image2)
plot.plot_result(image1,image2,result)
